# %%
import os
import sys
import math
import logging
from pathlib import Path

import numpy as np
import scipy as sp
import sklearn
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (16, 9.)})
sns.set_style("whitegrid")

import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

logging.basicConfig(level=logging.INFO, stream=sys.stdout)

# %%
from enadepy.loaders import read_interm
from enadepy.helpers import list_cols_socioecon
from sklearn.feature_selection import VarianceThreshold
from sklearn import preprocessing

# %% [markdown]
# In this pre-processing step, we use a previously filtered data containing only registries for students from public institutions.
#
# Here, we will select variables of interest by hand, as an initial automated approach did not show very interesting results.
#
# Related notebooks:
#
#     - 3.0-mc-preprocess-pub
#     - 4.0-mc-mining-pub

# %%
df = read_interm('../data/interim/microdados_enade_ata_2016a2018_pub.csv')

# %%
df.head()
# Out:
#    NU_ANO  NT_GER  CO_IES  CO_GRUPO  NU_IDADE TP_SEXO  ANO_FIM_EM  \
# 0    2016    52.9      56         6        26       M        2007
# 1    2016    74.4      56         6        23       M        2010
# 2    2016    60.2      56         6        26       F        2007
# 3    2016    70.6      56         6        25       F        2008
# 4    2016    30.9      56         6        25       F        2008
#
#    ANO_IN_GRAD QE_I01 QE_I02 QE_I04 QE_I05 QE_I06 QE_I07 QE_I08 QE_I09 QE_I10  \
# 0         2011      A      A      B      B      E      A      A      B      A
# 1         2012      A      A      D      D      B      C      B      B      A
# 2         2010      A      A      E      E      D      D      D      B      A
# 3         2012      A      A      E      D      D      A      D      B      A
# 4         2011      A      A      B      B      A      A      B      B      A
#
#   QE_I11 QE_I12 QE_I13 QE_I14 QE_I15 QE_I17 QE_I18 QE_I19 QE_I20 QE_I21  \
# 0      A      B      F      A      A      E      A      B      K      A
# 1      A      A      A      A      A      B      A      B      C      A
# 2      A      A      A      A      A      B      A      B      E      A
# 3      A      A      A      A      A      B      A      B      C      A
# 4      A      A      C      A      A      A      A      B      C      A
#
#   QE_I22 QE_I23 QE_I24 QE_I25
# 0      B      C      D      A
# 1      C      C      A      E
# 2      B      D      E      H
# 3      C      B      E      B
# 4      B      C      E      E

# %%
df.shape
# Out:
# (254, 31)

# %%
socio_cols = [col for col in df.columns if col.startswith('QE_')]

# %% [markdown]
# See all questions from the socioeconomics questionnaire and their results

# %%
dfmelt = df[socio_cols].melt(var_name="Question", value_name="Choice")

# %%
pd.crosstab(index=dfmelt['Question'], columns=dfmelt['Choice'])
# Out:
# Choice      A    B    C   D    E   F   G   H  I  J   K
# Question
# QE_I01    209   34    7   0    4   0   0   0  0  0   0
# QE_I02    193    9   10  40    0   2   0   0  0  0   0
# QE_I04      5   38   30  89   71  21   0   0  0  0   0
# QE_I05      3   30   35  85   69  32   0   0  0  0   0
# QE_I06     30  116   42  56    8   2   0   0  0  0   0
# QE_I07     58   28   57  71   19  17   4   0  0  0   0
# QE_I08     21   49   55  51   49  26   3   0  0  0   0
# QE_I09     10  162   56  13   11   2   0   0  0  0   0
# QE_I10    182   15   11  19   27   0   0   0  0  0   0
# QE_I11    149   78    0   0    8   0  11   6  2  0   0
# QE_I12    222   15    1   3    3  10   0   0  0  0   0
# QE_I13    146   58   39   1    4   6   0   0  0  0   0
# QE_I14    248    2    0   1    0   3   0   0  0  0   0
# QE_I15    241    0    5   4    2   2   0   0  0  0   0
# QE_I17    107  122    1  10   10   4   0   0  0  0   0
# QE_I18    231    6    3  13    1   0   0   0  0  0   0
# QE_I19     18  190   20   8    1   9   8   0  0  0   0
# QE_I20     59    5  125   6    7   1  24  13  0  1  13
# QE_I21    204   50    0   0    0   0   0   0  0  0   0
# QE_I22     34   78   70  28   44   0   0   0  0  0   0
# QE_I23      8   93   90  42   21   0   0   0  0  0   0
# QE_I24    105    1    6   8  134   0   0   0  0  0   0
# QE_I25     40   30   31   5   94   0   2  52  0  0   0

# %%
socio_sel_cols = ['QE_I02', 'QE_I04', 'QE_I05', 'QE_I06', 'QE_I07', 'QE_I08', 'QE_I09', 'QE_I17', 'QE_I22', 'QE_I23', 'QE_I25']

# %%
cols = socio_sel_cols + ['TP_SEXO', 'NT_GER']

# %%
cols
# Out:
# ['QE_I02',
#  'QE_I04',
#  'QE_I05',
#  'QE_I06',
#  'QE_I07',
#  'QE_I08',
#  'QE_I09',
#  'QE_I17',
#  'QE_I22',
#  'QE_I23',
#  'QE_I25',
#  'TP_SEXO',
#  'NT_GER']

# %% [markdown]
# ### Split data according to skin color

# %% [markdown]
# This split is necessary because there is a dominance of white students in the dataset. By splitting the data, we can look for patterns when students are not  white.

# %%
df.QE_I02.value_counts()
# Out:
# A    193
# D     40
# C     10
# B      9
# F      2
# Name: QE_I02, dtype: Int64

# %%
df_white = df.query('QE_I02 == "A"')[cols].drop(columns="QE_I02")
df_white
# Out:
#     QE_I04 QE_I05 QE_I06 QE_I07 QE_I08 QE_I09 QE_I17 QE_I22 QE_I23 QE_I25  \
# 0        B      B      E      A      A      B      E      B      C      A
# 1        D      D      B      C      B      B      B      C      C      E
# 2        E      E      D      D      D      B      B      B      D      H
# 3        E      D      D      A      D      B      B      C      B      B
# 4        B      B      A      A      B      B      A      B      C      E
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 249      E      D      C      B      B      E      A      B      D      B
# 250      C      B      B      D      C      B      A      C      C      H
# 251      C      D      B      D      C      A      A      B      D      E
# 252      D      D      B      G      D      B      B      A      B      H
# 253      D      D      B      D      B      B      A      C      C      H
#
#     TP_SEXO  NT_GER
# 0         M    52.9
# 1         M    74.4
# 2         F    60.2
# 3         F    70.6
# 4         F    30.9
# ..      ...     ...
# 249       F    53.9
# 250       F    49.2
# 251       M    41.3
# 252       F    59.1
# 253       F    33.5
#
# [193 rows x 12 columns]

# %%
df_black = df.query('QE_I02 in ["B", "D"]')[cols].drop(columns="QE_I02")
df_black
# Out:
#     QE_I04 QE_I05 QE_I06 QE_I07 QE_I08 QE_I09 QE_I17 QE_I22 QE_I23 QE_I25  \
# 9        C      D      D      A      D      B      B      A      B      D
# 13       E      E      E      B      A      A      B      C      C      A
# 15       E      E      D      A      E      B      B      B      B      E
# 38       D      B      F      C      B      B      A      A      B      A
# 48       D      E      C      B      E      B      B      C      B      E
# 54       F      F      D      A      E      C      B      A      D      E
# 69       E      E      D      A      E      B      F      E      E      H
# 82       E      D      D      A      E      F      B      C      B      H
# 87       D      D      D      C      C      B      B      B      B      A
# 102      F      E      D      A      D      B      A      C      C      H
# 121      B      B      B      C      B      B      B      D      B      E
# 138      D      D      D      A      B      B      B      B      B      C
# 141      F      F      B      E      E      B      B      E      B      B
# 148      E      E      B      D      B      B      B      B      B      E
# 153      D      D      B      C      B      C      A      D      B      E
# 155      B      B      C      D      B      A      A      E      B      B
# 156      B      B      C      F      A      B      A      A      C      A
# 157      D      B      B      D      B      A      A      E      B      B
# 160      B      D      C      C      C      B      A      B      C      A
# 161      B      A      C      B      B      A      A      C      C      E
# 163      C      D      C      C      E      E      A      D      D      H
# 164      D      C      C      B      C      C      A      E      B      C
# 165      D      F      B      D      B      B      A      E      B      H
# 167      D      D      B      F      C      C      A      D      A      E
# 168      C      C      B      D      B      B      D      C      B      A
# 172      C      D      B      D      A      C      A      B      D      E
# 174      C      C      C      C      A      C      A      C      C      B
# 176      D      C      C      D      B      C      A      D      B      C
# 177      B      D      B      F      C      D      A      D      B      H
# 178      B      B      B      C      B      E      A      B      C      H
# 180      B      E      B      D      B      C      A      D      B      A
# 182      D      F      B      E      E      C      B      D      D      A
# 183      B      B      C      B      C      E      D      C      B      C
# 184      B      B      C      C      B      C      A      D      D      C
# 190      D      D      B      C      B      C      A      B      B      C
# 195      D      E      B      B      B      B      B      E      C      B
# 198      D      B      C      D      A      C      D      E      C      E
# 201      D      D      B      D      E      D      A      C      A      E
# 202      F      C      C      D      F      B      B      D      E      H
# 209      D      B      B      C      C      B      B      C      C      D
# 212      A      B      B      F      B      C      A      C      C      H
# 213      D      D      B      G      D      C      A      C      B      B
# 214      C      C      B      F      B      C      A      B      B      H
# 216      D      D      B      C      E      C      A      B      B      E
# 219      B      B      B      D      A      C      A      E      C      H
# 226      D      D      C      E      A      B      A      B      C      C
# 234      B      B      C      A      C      E      D      E      B      A
# 241      D      D      C      B      D      C      A      B      D      E
# 246      D      B      C      D      A      C      D      C      C      E
#
#     TP_SEXO  NT_GER
# 9         F    67.2
# 13        F    61.1
# 15        M    51.7
# 38        F    60.4
# 48        F    63.0
# 54        F    75.4
# 69        F    59.9
# 82        M    39.2
# 87        M    70.6
# 102       F    54.2
# 121       F    62.3
# 138       M    56.8
# 141       M    61.6
# 148       F    42.6
# 153       F    55.9
# 155       F    40.6
# 156       F    45.8
# 157       F    71.5
# 160       F    47.3
# 161       F    70.0
# 163       F    58.5
# 164       F    46.5
# 165       F    47.1
# 167       F    60.6
# 168       M    39.4
# 172       M    36.8
# 174       F    28.7
# 176       F    35.2
# 177       F    46.7
# 178       F    22.8
# 180       F    38.3
# 182       M    50.8
# 183       F    25.0
# 184       M    45.5
# 190       M    48.9
# 195       F    52.7
# 198       M    39.5
# 201       M    62.0
# 202       F    52.8
# 209       F    38.9
# 212       F    37.0
# 213       F    61.3
# 214       F    51.4
# 216       F    37.3
# 219       F    38.2
# 226       F    42.8
# 234       M    34.2
# 241       F    36.1
# 246       F    27.0

# %% [markdown]
# ## Transforming data

# %%
for df_final, sufix in zip([df_white, df_black], ["white", "nowhite"]):
    df_final['NT_GER'] = pd.qcut(df_final.NT_GER, 2, labels=["Q0", "Q1"])
    cats = df_final.columns
    enc = preprocessing.OneHotEncoder(sparse=False)
    # fit and transform in one call and print categories
    out_enc = enc.fit_transform(df_final[cats])
    new_cols = enc.get_feature_names(cats).tolist()
    print(new_cols)
    # create temp. dataframe for concatenation with original data
    df_enc = pd.DataFrame(data=out_enc, columns=new_cols)
    df_enc.index = df_final.index
    # drop original columns and concatenate new encoded columns
    df_final.drop(cats, axis=1, inplace=True)
    df_final = pd.concat([df_final, df_enc], axis=1)
    print(df_final.columns)
    df_final.to_csv(f'../data/preprocessed/enade_2016a2018_pub_onehot_{sufix}.csv', index=False)
# Out:
# ['QE_I04_A', 'QE_I04_B', 'QE_I04_C', 'QE_I04_D', 'QE_I04_E', 'QE_I04_F', 'QE_I05_A', 'QE_I05_B', 'QE_I05_C', 'QE_I05_D', 'QE_I05_E', 'QE_I05_F', 'QE_I06_A', 'QE_I06_B', 'QE_I06_C', 'QE_I06_D', 'QE_I06_E', 'QE_I06_F', 'QE_I07_A', 'QE_I07_B', 'QE_I07_C', 'QE_I07_D', 'QE_I07_E', 'QE_I07_F', 'QE_I07_G', 'QE_I08_A', 'QE_I08_B', 'QE_I08_C', 'QE_I08_D', 'QE_I08_E', 'QE_I08_F', 'QE_I08_G', 'QE_I09_A', 'QE_I09_B', 'QE_I09_C', 'QE_I09_D', 'QE_I09_E', 'QE_I17_A', 'QE_I17_B', 'QE_I17_C', 'QE_I17_D', 'QE_I17_E', 'QE_I17_F', 'QE_I22_A', 'QE_I22_B', 'QE_I22_C', 'QE_I22_D', 'QE_I22_E', 'QE_I23_A', 'QE_I23_B', 'QE_I23_C', 'QE_I23_D', 'QE_I23_E', 'QE_I25_A', 'QE_I25_B', 'QE_I25_C', 'QE_I25_D', 'QE_I25_E', 'QE_I25_G', 'QE_I25_H', 'TP_SEXO_F', 'TP_SEXO_M', 'NT_GER_Q0', 'NT_GER_Q1']
# Index(['QE_I04_A', 'QE_I04_B', 'QE_I04_C', 'QE_I04_D', 'QE_I04_E', 'QE_I04_F',
#        'QE_I05_A', 'QE_I05_B', 'QE_I05_C', 'QE_I05_D', 'QE_I05_E', 'QE_I05_F',
#        'QE_I06_A', 'QE_I06_B', 'QE_I06_C', 'QE_I06_D', 'QE_I06_E', 'QE_I06_F',
#        'QE_I07_A', 'QE_I07_B', 'QE_I07_C', 'QE_I07_D', 'QE_I07_E', 'QE_I07_F',
#        'QE_I07_G', 'QE_I08_A', 'QE_I08_B', 'QE_I08_C', 'QE_I08_D', 'QE_I08_E',
#        'QE_I08_F', 'QE_I08_G', 'QE_I09_A', 'QE_I09_B', 'QE_I09_C', 'QE_I09_D',
#        'QE_I09_E', 'QE_I17_A', 'QE_I17_B', 'QE_I17_C', 'QE_I17_D', 'QE_I17_E',
#        'QE_I17_F', 'QE_I22_A', 'QE_I22_B', 'QE_I22_C', 'QE_I22_D', 'QE_I22_E',
#        'QE_I23_A', 'QE_I23_B', 'QE_I23_C', 'QE_I23_D', 'QE_I23_E', 'QE_I25_A',
#        'QE_I25_B', 'QE_I25_C', 'QE_I25_D', 'QE_I25_E', 'QE_I25_G', 'QE_I25_H',
#        'TP_SEXO_F', 'TP_SEXO_M', 'NT_GER_Q0', 'NT_GER_Q1'],
#       dtype='object')
# ['QE_I04_A', 'QE_I04_B', 'QE_I04_C', 'QE_I04_D', 'QE_I04_E', 'QE_I04_F', 'QE_I05_A', 'QE_I05_B', 'QE_I05_C', 'QE_I05_D', 'QE_I05_E', 'QE_I05_F', 'QE_I06_B', 'QE_I06_C', 'QE_I06_D', 'QE_I06_E', 'QE_I06_F', 'QE_I07_A', 'QE_I07_B', 'QE_I07_C', 'QE_I07_D', 'QE_I07_E', 'QE_I07_F', 'QE_I07_G', 'QE_I08_A', 'QE_I08_B', 'QE_I08_C', 'QE_I08_D', 'QE_I08_E', 'QE_I08_F', 'QE_I09_A', 'QE_I09_B', 'QE_I09_C', 'QE_I09_D', 'QE_I09_E', 'QE_I09_F', 'QE_I17_A', 'QE_I17_B', 'QE_I17_D', 'QE_I17_F', 'QE_I22_A', 'QE_I22_B', 'QE_I22_C', 'QE_I22_D', 'QE_I22_E', 'QE_I23_A', 'QE_I23_B', 'QE_I23_C', 'QE_I23_D', 'QE_I23_E', 'QE_I25_A', 'QE_I25_B', 'QE_I25_C', 'QE_I25_D', 'QE_I25_E', 'QE_I25_H', 'TP_SEXO_F', 'TP_SEXO_M', 'NT_GER_Q0', 'NT_GER_Q1']
# Index(['QE_I04_A', 'QE_I04_B', 'QE_I04_C', 'QE_I04_D', 'QE_I04_E', 'QE_I04_F',
#        'QE_I05_A', 'QE_I05_B', 'QE_I05_C', 'QE_I05_D', 'QE_I05_E', 'QE_I05_F',
#        'QE_I06_B', 'QE_I06_C', 'QE_I06_D', 'QE_I06_E', 'QE_I06_F', 'QE_I07_A',
#        'QE_I07_B', 'QE_I07_C', 'QE_I07_D', 'QE_I07_E', 'QE_I07_F', 'QE_I07_G',
#        'QE_I08_A', 'QE_I08_B', 'QE_I08_C', 'QE_I08_D', 'QE_I08_E', 'QE_I08_F',
#        'QE_I09_A', 'QE_I09_B', 'QE_I09_C', 'QE_I09_D', 'QE_I09_E', 'QE_I09_F',
#        'QE_I17_A', 'QE_I17_B', 'QE_I17_D', 'QE_I17_F', 'QE_I22_A', 'QE_I22_B',
#        'QE_I22_C', 'QE_I22_D', 'QE_I22_E', 'QE_I23_A', 'QE_I23_B', 'QE_I23_C',
#        'QE_I23_D', 'QE_I23_E', 'QE_I25_A', 'QE_I25_B', 'QE_I25_C', 'QE_I25_D',
#        'QE_I25_E', 'QE_I25_H', 'TP_SEXO_F', 'TP_SEXO_M', 'NT_GER_Q0',
#        'NT_GER_Q1'],
#       dtype='object')
