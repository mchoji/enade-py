# %%
import os
import sys
import math
import logging
from pathlib import Path

import numpy as np
import scipy as sp
import sklearn
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (16, 9.)})
sns.set_style("whitegrid")

import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)
pd.set_option("mode.chained_assignment", "raise")

logging.basicConfig(level=logging.INFO, stream=sys.stdout)

# %%
from enadepy import *
from enadepy import transform
from enadepy.helpers import *
from enadepy.loaders import read_interm

# %%
index_co_ies = {
    56: 'UNESP', # pública estadual
    322: 'UNIP', # Privada com fins lucrativos
    845: 'FAC-FEA', # Pública municipal
    1418: 'UNITOLEDO', # Privada com fins lucrativos
    2289: 'UCESP',  # Privada sem fins lucrativos
    4522: 'UNISALESIANO',  # Privada sem fins lucrativos
    15697: 'FATEC' # pública estadual
}

# %%
df = read_interm('../data/interim/microdados_enade_aracatuba_2016a2018_min.csv')

# %%
df.shape
# Out:
# (2075, 45)

# %%
df.head()
# Out:
#    NU_ANO  TP_PRES  NT_GER  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  \
# 0    2016      555    52.9      56       10001       10028         6
# 1    2016      555    74.4      56       10001       10028         6
# 2    2016      555    60.2      56       10001       10028         6
# 3    2016      555    70.6      56       10001       10028         6
# 4    2016      555    30.9      56       10001       10028         6
#
#    CO_CURSO  CO_MODALIDADE  CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO  \
# 0      3161              1         3502804           35                3
# 1      3161              1         3502804           35                3
# 2      3161              1         3502804           35                3
# 3      3161              1         3502804           35                3
# 4      3161              1         3502804           35                3
#
#    NU_IDADE TP_SEXO  ANO_FIM_EM  ANO_IN_GRAD  CO_TURNO_GRADUACAO  \
# 0        26       M        2007         2011                   3
# 1        23       M        2010         2012                   3
# 2        26       F        2007         2010                   3
# 3        25       F        2008         2012                   3
# 4        25       F        2008         2011                   4
#
#    TP_INSCRICAO_ADM  TP_INSCRICAO QE_I01 QE_I02 QE_I03 QE_I04 QE_I05 QE_I06  \
# 0              <NA>          <NA>      A      A      A      B      B      E
# 1              <NA>          <NA>      A      A      A      D      D      B
# 2              <NA>          <NA>      A      A      A      E      E      D
# 3              <NA>          <NA>      A      A      A      E      D      D
# 4              <NA>          <NA>      A      A      A      B      B      A
#
#   QE_I07 QE_I08 QE_I09 QE_I10 QE_I11 QE_I12 QE_I13 QE_I14 QE_I15  QE_I16  \
# 0      A      A      B      A      A      B      F      A      A      35
# 1      C      B      B      A      A      A      A      A      A      35
# 2      D      D      B      A      A      A      A      A      A      35
# 3      A      D      B      A      A      A      A      A      A      35
# 4      A      B      B      A      A      A      C      A      A      35
#
#   QE_I17 QE_I18 QE_I19 QE_I20 QE_I21 QE_I22 QE_I23 QE_I24 QE_I25 QE_I26
# 0      E      A      B      K      A      B      C      D      A      A
# 1      B      A      B      C      A      C      C      A      E      F
# 2      B      A      B      E      A      B      D      E      H      F
# 3      B      A      B      C      A      C      B      E      B      F
# 4      A      A      B      C      A      B      C      E      E      F

# %%
df['TP_PRES'].value_counts()
# Out:
# 555    1802
# 222     273
# Name: TP_PRES, dtype: Int64

# %%
df.describe().transpose()
# Out:
#                      count          mean           std        min        25%  \
# NU_ANO              2075.0  2.017184e+03  7.679209e-01     2016.0     2017.0
# TP_PRES             2075.0  5.111884e+02  1.125873e+02      222.0      555.0
# NT_GER              1802.0  4.690316e+01  1.350187e+01        5.4       37.2
# CO_IES              2075.0  2.351158e+03  2.347572e+03       56.0      845.0
# CO_CATEGAD          2075.0  6.523145e+03  5.269747e+03        2.0        5.0
# CO_ORGACAD          2075.0  1.002198e+04  3.386354e+00    10020.0    10020.0
# CO_GRUPO            2075.0  1.510725e+03  2.322988e+03        1.0        5.0
# CO_CURSO            2075.0  7.461795e+05  1.231741e+06     3161.0    20642.0
# CO_MODALIDADE       2075.0  1.000000e+00  0.000000e+00        1.0        1.0
# CO_MUNIC_CURSO      2075.0  3.502804e+06  0.000000e+00  3502804.0  3502804.0
# CO_UF_CURSO         2075.0  3.500000e+01  0.000000e+00       35.0       35.0
# CO_REGIAO_CURSO     2075.0  3.000000e+00  0.000000e+00        3.0        3.0
# NU_IDADE            2075.0  2.611711e+01  6.548408e+00       19.0       22.0
# ANO_FIM_EM          2075.0  2.009610e+03  5.268116e+00     1973.0     2009.0
# ANO_IN_GRAD         2075.0  2.013473e+03  1.393471e+00     2005.0     2013.0
# CO_TURNO_GRADUACAO  2075.0  3.609157e+00  9.490456e-01        1.0        4.0
# TP_INSCRICAO_ADM    1619.0  0.000000e+00  0.000000e+00        0.0        0.0
# TP_INSCRICAO        1619.0  4.830142e-01  4.998658e-01        0.0        0.0
# QE_I16              1993.0  3.548419e+01  5.463633e+00       11.0       35.0
#
#                            50%        75%        max
# NU_ANO                 2017.00     2018.0     2018.0
# TP_PRES                 555.00      555.0      555.0
# NT_GER                   46.05       56.9       85.6
# CO_IES                 1418.00     4522.0    15697.0
# CO_CATEGAD            10005.00    10007.0    17634.0
# CO_ORGACAD            10020.00    10022.0    10028.0
# CO_GRUPO                 23.00     3501.0     6306.0
# CO_CURSO              96729.00  1147234.0  5000425.0
# CO_MODALIDADE             1.00        1.0        1.0
# CO_MUNIC_CURSO      3502804.00  3502804.0  3502804.0
# CO_UF_CURSO              35.00       35.0       35.0
# CO_REGIAO_CURSO           3.00        3.0        3.0
# NU_IDADE                 24.00       27.0       64.0
# ANO_FIM_EM             2011.00     2013.0     2016.0
# ANO_IN_GRAD            2013.00     2014.0     2018.0
# CO_TURNO_GRADUACAO        4.00        4.0        4.0
# TP_INSCRICAO_ADM          0.00        0.0        0.0
# TP_INSCRICAO              0.00        1.0        1.0
# QE_I16                   35.00       35.0       99.0

# %% [markdown]
# ### Check for NaN values in some columns of interest

# %%
df.query('TP_PRES == 555').NT_GER.isna().value_counts()
# Out:
# False    1802
# Name: NT_GER, dtype: int64

# %%
cols = list_cols_socioecon()
cols.remove('QE_I16')

# %%
cols
# Out:
# ['QE_I01',
#  'QE_I02',
#  'QE_I03',
#  'QE_I04',
#  'QE_I05',
#  'QE_I06',
#  'QE_I07',
#  'QE_I08',
#  'QE_I09',
#  'QE_I10',
#  'QE_I11',
#  'QE_I12',
#  'QE_I13',
#  'QE_I14',
#  'QE_I15',
#  'QE_I17',
#  'QE_I18',
#  'QE_I19',
#  'QE_I20',
#  'QE_I21',
#  'QE_I22',
#  'QE_I23',
#  'QE_I24',
#  'QE_I25',
#  'QE_I26']

# %%
df.query('TP_PRES == 555')[cols].isna().sum()
# Out:
# QE_I01      1
# QE_I02      1
# QE_I03      1
# QE_I04      1
# QE_I05      1
# QE_I06      1
# QE_I07      1
# QE_I08      1
# QE_I09      1
# QE_I10      1
# QE_I11      1
# QE_I12      1
# QE_I13      1
# QE_I14      1
# QE_I15      1
# QE_I17      1
# QE_I18      1
# QE_I19      1
# QE_I20      1
# QE_I21      1
# QE_I22      1
# QE_I23      1
# QE_I24      1
# QE_I25      1
# QE_I26    601
# dtype: int64

# %%
df.query('TP_PRES == 555')[[x for x in cols if x != 'QE_I26']].isna().any(axis=1).value_counts()
# Out:
# False    1801
# True        1
# dtype: int64

# %% [markdown]
# #### Summary
#
# Among those entries with TP_PRES == 555, several have invalid values for QE_I26 and just one row has NaN values for all attributes.
#
# So, we choose to remove QE_I26 entirely and the null row as well.

# %%
cols_keep = [x for x in cols if x != 'QE_I26']
df2 = df.query('TP_PRES == 555').dropna(axis=0, subset=cols_keep).copy()

# %%
df2
# Out:
#       NU_ANO  TP_PRES  NT_GER  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  \
# 0       2016      555    52.9      56       10001       10028         6
# 1       2016      555    74.4      56       10001       10028         6
# 2       2016      555    60.2      56       10001       10028         6
# 3       2016      555    70.6      56       10001       10028         6
# 4       2016      555    30.9      56       10001       10028         6
# ...      ...      ...     ...     ...         ...         ...       ...
# 2062    2018      555    48.5     322       10005       10028         2
# 2063    2018      555    27.5     322       10005       10028         2
# 2067    2018      555    48.0     322       10005       10028         2
# 2072    2018      555    36.2     322       10005       10028         2
# 2074    2018      555    55.0     322       10005       10028       804
#
#       CO_CURSO  CO_MODALIDADE  CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO  \
# 0         3161              1         3502804           35                3
# 1         3161              1         3502804           35                3
# 2         3161              1         3502804           35                3
# 3         3161              1         3502804           35                3
# 4         3161              1         3502804           35                3
# ...        ...            ...             ...          ...              ...
# 2062     19524              1         3502804           35                3
# 2063     19524              1         3502804           35                3
# 2067     19524              1         3502804           35                3
# 2072     19524              1         3502804           35                3
# 2074     17019              1         3502804           35                3
#
#       NU_IDADE TP_SEXO  ANO_FIM_EM  ANO_IN_GRAD  CO_TURNO_GRADUACAO  \
# 0           26       M        2007         2011                   3
# 1           23       M        2010         2012                   3
# 2           26       F        2007         2010                   3
# 3           25       F        2008         2012                   3
# 4           25       F        2008         2011                   4
# ...        ...     ...         ...          ...                 ...
# 2062        24       M        2016         2017                   4
# 2063        27       F        2009         2012                   4
# 2067        23       F        2016         2017                   4
# 2072        25       F        2011         2013                   4
# 2074        34       M        2002         2011                   4
#
#       TP_INSCRICAO_ADM  TP_INSCRICAO QE_I01 QE_I02 QE_I03 QE_I04 QE_I05  \
# 0                 <NA>          <NA>      A      A      A      B      B
# 1                 <NA>          <NA>      A      A      A      D      D
# 2                 <NA>          <NA>      A      A      A      E      E
# 3                 <NA>          <NA>      A      A      A      E      D
# 4                 <NA>          <NA>      A      A      A      B      B
# ...                ...           ...    ...    ...    ...    ...    ...
# 2062                 0             0      A      A      A      B      C
# 2063                 0             0      E      D      A      B      B
# 2067                 0             0      A      A      A      E      D
# 2072                 0             0      A      A      A      D      F
# 2074                 0             0      A      A      A      D      E
#
#      QE_I06 QE_I07 QE_I08 QE_I09 QE_I10 QE_I11 QE_I12 QE_I13 QE_I14 QE_I15  \
# 0         E      A      A      B      A      A      B      F      A      A
# 1         B      C      B      B      A      A      A      A      A      A
# 2         D      D      D      B      A      A      A      A      A      A
# 3         D      A      D      B      A      A      A      A      A      A
# 4         A      A      B      B      A      A      A      C      A      A
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2062      A      A      B      C      E      B      A      A      A      A
# 2063      C      B      A      B      A      E      A      A      A      D
# 2067      B      C      D      B      A      B      A      A      A      A
# 2072      A      A      A      C      A      H      A      F      A      A
# 2074      D      B      E      E      E      B      A      A      A      A
#
#       QE_I16 QE_I17 QE_I18 QE_I19 QE_I20 QE_I21 QE_I22 QE_I23 QE_I24 QE_I25  \
# 0         35      E      A      B      K      A      B      C      D      A
# 1         35      B      A      B      C      A      C      C      A      E
# 2         35      B      A      B      E      A      B      D      E      H
# 3         35      B      A      B      C      A      C      B      E      B
# 4         35      A      A      B      C      A      B      C      E      E
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2062      35      A      A      A      C      B      E      D      E      E
# 2063      35      A      A      A      A      B      B      A      E      E
# 2067      35      E      A      C      A      A      B      B      E      E
# 2072      35      B      A      B      A      A      C      B      E      H
# 2074      35      A      A      F      G      A      C      B      E      E
#
#      QE_I26
# 0         A
# 1         F
# 2         F
# 3         F
# 4         F
# ...     ...
# 2062   <NA>
# 2063   <NA>
# 2067      C
# 2072   <NA>
# 2074      B
#
# [1801 rows x 45 columns]

# %%
df2[list_cols_socioecon()].isna().sum()
# Out:
# QE_I01      0
# QE_I02      0
# QE_I03      0
# QE_I04      0
# QE_I05      0
# QE_I06      0
# QE_I07      0
# QE_I08      0
# QE_I09      0
# QE_I10      0
# QE_I11      0
# QE_I12      0
# QE_I13      0
# QE_I14      0
# QE_I15      0
# QE_I16      0
# QE_I17      0
# QE_I18      0
# QE_I19      0
# QE_I20      0
# QE_I21      0
# QE_I22      0
# QE_I23      0
# QE_I24      0
# QE_I25      0
# QE_I26    600
# dtype: int64

# %%
df_dropped = df2.drop(columns=['QE_I26']).copy()

# %%
dfmelt = df_dropped[cols_keep].melt(var_name="Questão", value_name="Escolha")

# %%
pd.crosstab(index=dfmelt['Questão'], columns=dfmelt['Escolha'])
# Out:
# Escolha     A     B    C    D     E    F    G    H   I   J   K
# Questão
# QE_I01   1478   258   27    6    32    0    0    0   0   0   0
# QE_I02   1305    92   55  338     1   10    0    0   0   0   0
# QE_I03   1788     8    5    0     0    0    0    0   0   0   0
# QE_I04     53   345  311  723   302   67    0    0   0   0   0
# QE_I05     29   287  341  698   341  105    0    0   0   0   0
# QE_I06    114  1266  317   92     8    4    0    0   0   0   0
# QE_I07    149   247  471  570   251   79   20   14   0   0   0
# QE_I08    233   552  453  239   215   98   11    0   0   0   0
# QE_I09    135   623  554  178   219   92    0    0   0   0   0
# QE_I10    804   139  118  160   580    0    0    0   0   0   0
# QE_I11    155   751  184   30   364   16   77  183  21  16   4
# QE_I12   1697    17    4    3     8   72    0    0   0   0   0
# QE_I13   1491   104   41    7     5  153    0    0   0   0   0
# QE_I14   1769     5    0    1    16   10    0    0   0   0   0
# QE_I15   1569     8   81   79    39   25    0    0   0   0   0
# QE_I17   1201   434    6   73    79    8    0    0   0   0   0
# QE_I18   1663    78   15   40     5    0    0    0   0   0   0
# QE_I19    202  1283  114   61     9   71   61    0   0   0   0
# QE_I20    549    39  788   29    35    6  132  124   8  12  79
# QE_I21   1119   682    0    0     0    0    0    0   0   0   0
# QE_I22    151   546  518  196   390    0    0    0   0   0   0
# QE_I23     50   693  499  217   342    0    0    0   0   0   0
# QE_I24    567     8   14   44  1168    0    0    0   0   0   0
# QE_I25    493   134  291   21   584    3    3  272   0   0   0

# %%
df_dropped['QE_I16'].value_counts()
# Out:
# 35    1698
# 50      21
# 31      18
# 99      10
# 33       9
# 17       8
# 52       7
# 41       7
# 51       5
# 43       3
# 29       3
# 53       2
# 27       2
# 26       2
# 21       2
# 15       1
# 12       1
# 32       1
# 11       1
# Name: QE_I16, dtype: Int64

# %%
df_dropped.drop(columns=['QE_I16'], inplace=True)

# %%
cols_keep
# Out:
# ['QE_I01',
#  'QE_I02',
#  'QE_I03',
#  'QE_I04',
#  'QE_I05',
#  'QE_I06',
#  'QE_I07',
#  'QE_I08',
#  'QE_I09',
#  'QE_I10',
#  'QE_I11',
#  'QE_I12',
#  'QE_I13',
#  'QE_I14',
#  'QE_I15',
#  'QE_I17',
#  'QE_I18',
#  'QE_I19',
#  'QE_I20',
#  'QE_I21',
#  'QE_I22',
#  'QE_I23',
#  'QE_I24',
#  'QE_I25']

# %%
df_dropped.groupby('CO_IES').nunique().CO_CURSO
# Out:
# CO_IES
# 56        2
# 322      15
# 845       3
# 1418     19
# 2289      2
# 4522     22
# 15697     1
# Name: CO_CURSO, dtype: int64

# %%
df_dropped.groupby('CO_IES').size()
# Out:
# CO_IES
# 56       149
# 322      301
# 845       97
# 1418     653
# 2289      43
# 4522     550
# 15697      8
# dtype: int64

# %%
len(df_dropped)
# Out:
# 1801

# %%
print(df_dropped.groupby('CO_IES').agg({'CO_CURSO': ['nunique'], 'TP_PRES': ['size']}).to_latex())
# Out:
# \begin{tabular}{lrr}
# \toprule
# {} & CO\_CURSO & TP\_PRES \\
# {} &  nunique &    size \\
# CO\_IES &          &         \\
# \midrule
# 56     &        2 &     149 \\
# 322    &       15 &     301 \\
# 845    &        3 &      97 \\
# 1418   &       19 &     653 \\
# 2289   &        2 &      43 \\
# 4522   &       22 &     550 \\
# 15697  &        1 &       8 \\
# \bottomrule
# \end{tabular}

# %%
df_dropped.groupby('CO_IES').agg({'CO_CURSO': ['nunique'], 'TP_PRES': ['size']})
# Out:
#        CO_CURSO TP_PRES
#         nunique    size
# CO_IES
# 56            2     149
# 322          15     301
# 845           3      97
# 1418         19     653
# 2289          2      43
# 4522         22     550
# 15697         1       8

# %%
df_dropped.query('CO_IES in [56, 322, 1418, 4522]').groupby(['CO_CATEGAD', 'CO_IES']).size()
# Out:
# CO_CATEGAD  CO_IES
# 4           322       173
#             1418      242
# 5           4522      215
# 10001       56        149
# 10005       322        90
#             1418      411
# 10007       4522      179
# 10008       322        38
#             4522      156
# dtype: int64

# %%
df_dropped.groupby(['CO_CATEGAD', 'CO_IES']).size()
# Out:
# CO_CATEGAD  CO_IES
# 2           15697       8
# 3           845        19
# 4           322       173
#             1418      242
# 5           2289       11
#             4522      215
# 10001       56        149
# 10005       322        90
#             1418      411
# 10007       4522      179
# 10008       322        38
#             2289       32
#             4522      156
# 17634       845        78
# dtype: int64

# %%
df_dropped.loc[:,'CO_IES'].map(index_co_ies,)
# Out:
# 0       UNESP
# 1       UNESP
# 2       UNESP
# 3       UNESP
# 4       UNESP
#         ...
# 2062     UNIP
# 2063     UNIP
# 2067     UNIP
# 2072     UNIP
# 2074     UNIP
# Name: CO_IES, Length: 1801, dtype: object

# %%
df_dropped.columns
# Out:
# Index(['NU_ANO', 'TP_PRES', 'NT_GER', 'CO_IES', 'CO_CATEGAD', 'CO_ORGACAD',
#        'CO_GRUPO', 'CO_CURSO', 'CO_MODALIDADE', 'CO_MUNIC_CURSO',
#        'CO_UF_CURSO', 'CO_REGIAO_CURSO', 'NU_IDADE', 'TP_SEXO', 'ANO_FIM_EM',
#        'ANO_IN_GRAD', 'CO_TURNO_GRADUACAO', 'TP_INSCRICAO_ADM', 'TP_INSCRICAO',
#        'QE_I01', 'QE_I02', 'QE_I03', 'QE_I04', 'QE_I05', 'QE_I06', 'QE_I07',
#        'QE_I08', 'QE_I09', 'QE_I10', 'QE_I11', 'QE_I12', 'QE_I13', 'QE_I14',
#        'QE_I15', 'QE_I17', 'QE_I18', 'QE_I19', 'QE_I20', 'QE_I21', 'QE_I22',
#        'QE_I23', 'QE_I24', 'QE_I25'],
#       dtype='object')

# %% [markdown]
# ### Check if data needs some additional filtering

# %%
df_dropped.TP_PRES.unique()
# Out:
# <IntegerArray>
# [555]
# Length: 1, dtype: Int64

# %%
df_dropped.loc[df_dropped.TP_PRES==222,:]
# Out:
# Empty DataFrame
# Columns: [NU_ANO, TP_PRES, NT_GER, CO_IES, CO_CATEGAD, CO_ORGACAD, CO_GRUPO, CO_CURSO, CO_MODALIDADE, CO_MUNIC_CURSO, CO_UF_CURSO, CO_REGIAO_CURSO, NU_IDADE, TP_SEXO, ANO_FIM_EM, ANO_IN_GRAD, CO_TURNO_GRADUACAO, TP_INSCRICAO_ADM, TP_INSCRICAO, QE_I01, QE_I02, QE_I03, QE_I04, QE_I05, QE_I06, QE_I07, QE_I08, QE_I09, QE_I10, QE_I11, QE_I12, QE_I13, QE_I14, QE_I15, QE_I17, QE_I18, QE_I19, QE_I20, QE_I21, QE_I22, QE_I23, QE_I24, QE_I25]
# Index: []

# %%
len(df_dropped.query('NU_ANO==2018').index)
# Out:
# 721

# %%
dfmelt = df_dropped[cols_keep].melt(var_name="Questão", value_name="Escolha")

# %%
pd.crosstab(index=dfmelt['Questão'], columns=dfmelt['Escolha'])
# Out:
# Escolha     A     B    C    D     E    F    G    H   I   J   K
# Questão
# QE_I01   1478   258   27    6    32    0    0    0   0   0   0
# QE_I02   1305    92   55  338     1   10    0    0   0   0   0
# QE_I03   1788     8    5    0     0    0    0    0   0   0   0
# QE_I04     53   345  311  723   302   67    0    0   0   0   0
# QE_I05     29   287  341  698   341  105    0    0   0   0   0
# QE_I06    114  1266  317   92     8    4    0    0   0   0   0
# QE_I07    149   247  471  570   251   79   20   14   0   0   0
# QE_I08    233   552  453  239   215   98   11    0   0   0   0
# QE_I09    135   623  554  178   219   92    0    0   0   0   0
# QE_I10    804   139  118  160   580    0    0    0   0   0   0
# QE_I11    155   751  184   30   364   16   77  183  21  16   4
# QE_I12   1697    17    4    3     8   72    0    0   0   0   0
# QE_I13   1491   104   41    7     5  153    0    0   0   0   0
# QE_I14   1769     5    0    1    16   10    0    0   0   0   0
# QE_I15   1569     8   81   79    39   25    0    0   0   0   0
# QE_I17   1201   434    6   73    79    8    0    0   0   0   0
# QE_I18   1663    78   15   40     5    0    0    0   0   0   0
# QE_I19    202  1283  114   61     9   71   61    0   0   0   0
# QE_I20    549    39  788   29    35    6  132  124   8  12  79
# QE_I21   1119   682    0    0     0    0    0    0   0   0   0
# QE_I22    151   546  518  196   390    0    0    0   0   0   0
# QE_I23     50   693  499  217   342    0    0    0   0   0   0
# QE_I24    567     8   14   44  1168    0    0    0   0   0   0
# QE_I25    493   134  291   21   584    3    3  272   0   0   0

# %%
df_dropped.drop(columns=['QE_I03'], inplace=True)

# %% [markdown]
# ### Checking for NaN values for a subset of columns:

# %%
df_dropped.drop(columns=['TP_PRES', 'NT_GER', 'CO_CATEGAD', 'CO_ORGACAD', 'CO_CURSO', 'CO_MODALIDADE', 'CO_MUNIC_CURSO',
                        'CO_UF_CURSO', 'CO_REGIAO_CURSO', 'CO_TURNO_GRADUACAO', 'TP_INSCRICAO', 'TP_INSCRICAO_ADM']).isna().sum()
# Out:
# NU_ANO         0
# CO_IES         0
# CO_GRUPO       0
# NU_IDADE       0
# TP_SEXO        0
# ANO_FIM_EM     0
# ANO_IN_GRAD    0
# QE_I01         0
# QE_I02         0
# QE_I04         0
# QE_I05         0
# QE_I06         0
# QE_I07         0
# QE_I08         0
# QE_I09         0
# QE_I10         0
# QE_I11         0
# QE_I12         0
# QE_I13         0
# QE_I14         0
# QE_I15         0
# QE_I17         0
# QE_I18         0
# QE_I19         0
# QE_I20         0
# QE_I21         0
# QE_I22         0
# QE_I23         0
# QE_I24         0
# QE_I25         0
# dtype: int64

# %% [markdown]
# No NaN values found, so make a new dataframe to above configuration.

# %%
df_dropped2 = df_dropped.drop(columns=['TP_PRES', 'CO_CATEGAD', 'CO_ORGACAD', 'CO_CURSO', 'CO_MODALIDADE', 'CO_MUNIC_CURSO',
                        'CO_UF_CURSO', 'CO_REGIAO_CURSO', 'CO_TURNO_GRADUACAO', 'TP_INSCRICAO', 'TP_INSCRICAO_ADM'])

# %%
cat_cols_tmp = ['NU_ANO', 'TP_PRES'] + list_cols_institution() + list_cols_student(exclude=['NU_IDADE', 'TP_INSCRICAO', 'TP_INSCRICAO_ADM']) + list_cols_socioecon()

# %%
cat_cols = list(set(cat_cols_tmp).intersection(df_dropped2.columns))
cat_cols.sort()
cat_cols
# Out:
# ['ANO_FIM_EM',
#  'ANO_IN_GRAD',
#  'CO_GRUPO',
#  'CO_IES',
#  'NU_ANO',
#  'QE_I01',
#  'QE_I02',
#  'QE_I04',
#  'QE_I05',
#  'QE_I06',
#  'QE_I07',
#  'QE_I08',
#  'QE_I09',
#  'QE_I10',
#  'QE_I11',
#  'QE_I12',
#  'QE_I13',
#  'QE_I14',
#  'QE_I15',
#  'QE_I17',
#  'QE_I18',
#  'QE_I19',
#  'QE_I20',
#  'QE_I21',
#  'QE_I22',
#  'QE_I23',
#  'QE_I24',
#  'QE_I25',
#  'TP_SEXO']

# %%
df3 = transform.categorize(df_dropped2, cat_cols)

# %%
df3[cat_cols].describe()
# Out:
#         ANO_FIM_EM  ANO_IN_GRAD  CO_GRUPO  CO_IES  NU_ANO QE_I01 QE_I02  \
# count         1801         1801      1801    1801    1801   1801   1801
# unique          38           13        34       7       3      5      6
# top           2012         2013         2    1418    2018      A      A
# freq           429          646       319     653     721   1478   1305
#
#        QE_I04 QE_I05 QE_I06 QE_I07 QE_I08 QE_I09 QE_I10 QE_I11 QE_I12 QE_I13  \
# count    1801   1801   1801   1801   1801   1801   1801   1801   1801   1801
# unique      6      6      6      8      7      6      5     11      6      6
# top         D      D      B      D      B      B      A      B      A      A
# freq      723    698   1266    570    552    623    804    751   1697   1491
#
#        QE_I14 QE_I15 QE_I17 QE_I18 QE_I19 QE_I20 QE_I21 QE_I22 QE_I23 QE_I24  \
# count    1801   1801   1801   1801   1801   1801   1801   1801   1801   1801
# unique      5      6      6      5      7     11      2      5      5      5
# top         A      A      A      A      B      C      A      B      B      E
# freq     1769   1569   1201   1663   1283    788   1119    546    693   1168
#
#        QE_I25 TP_SEXO
# count    1801    1801
# unique      8       2
# top         E       F
# freq      584    1009

# %%
df3.describe()
# Out:
#             NT_GER     NU_IDADE
# count  1801.000000  1801.000000
# mean     46.915103    25.872293
# std      13.496100     6.499343
# min       5.400000    19.000000
# 25%      37.200000    22.000000
# 50%      46.100000    23.000000
# 75%      56.900000    27.000000
# max      85.600000    64.000000

# %%
df3.columns
# Out:
# Index(['NU_ANO', 'NT_GER', 'CO_IES', 'CO_GRUPO', 'NU_IDADE', 'TP_SEXO',
#        'ANO_FIM_EM', 'ANO_IN_GRAD', 'QE_I01', 'QE_I02', 'QE_I04', 'QE_I05',
#        'QE_I06', 'QE_I07', 'QE_I08', 'QE_I09', 'QE_I10', 'QE_I11', 'QE_I12',
#        'QE_I13', 'QE_I14', 'QE_I15', 'QE_I17', 'QE_I18', 'QE_I19', 'QE_I20',
#        'QE_I21', 'QE_I22', 'QE_I23', 'QE_I24', 'QE_I25'],
#       dtype='object')

# %%
#sns.pairplot(df3.loc[:,['CO_IES', 'CO_CURSO', 'NU_IDADE', 'TP_SEXO']])

# %%
df3 = transform.categorize(df_dropped2, cat_cols, only_current=True)

# %%
df3.count()
# Out:
# NU_ANO         1801
# NT_GER         1801
# CO_IES         1801
# CO_GRUPO       1801
# NU_IDADE       1801
# TP_SEXO        1801
# ANO_FIM_EM     1801
# ANO_IN_GRAD    1801
# QE_I01         1801
# QE_I02         1801
# QE_I04         1801
# QE_I05         1801
# QE_I06         1801
# QE_I07         1801
# QE_I08         1801
# QE_I09         1801
# QE_I10         1801
# QE_I11         1801
# QE_I12         1801
# QE_I13         1801
# QE_I14         1801
# QE_I15         1801
# QE_I17         1801
# QE_I18         1801
# QE_I19         1801
# QE_I20         1801
# QE_I21         1801
# QE_I22         1801
# QE_I23         1801
# QE_I24         1801
# QE_I25         1801
# dtype: int64

# %%
df3[cat_cols].describe()
# Out:
#         ANO_FIM_EM  ANO_IN_GRAD  CO_GRUPO  CO_IES  NU_ANO QE_I01 QE_I02  \
# count         1801         1801      1801    1801    1801   1801   1801
# unique          38           13        34       7       3      5      6
# top           2012         2013         2    1418    2018      A      A
# freq           429          646       319     653     721   1478   1305
#
#        QE_I04 QE_I05 QE_I06 QE_I07 QE_I08 QE_I09 QE_I10 QE_I11 QE_I12 QE_I13  \
# count    1801   1801   1801   1801   1801   1801   1801   1801   1801   1801
# unique      6      6      6      8      7      6      5     11      6      6
# top         D      D      B      D      B      B      A      B      A      A
# freq      723    698   1266    570    552    623    804    751   1697   1491
#
#        QE_I14 QE_I15 QE_I17 QE_I18 QE_I19 QE_I20 QE_I21 QE_I22 QE_I23 QE_I24  \
# count    1801   1801   1801   1801   1801   1801   1801   1801   1801   1801
# unique      5      6      6      5      7     11      2      5      5      5
# top         A      A      A      A      B      C      A      B      B      E
# freq     1769   1569   1201   1663   1283    788   1119    546    693   1168
#
#        QE_I25 TP_SEXO
# count    1801    1801
# unique      8       2
# top         E       F
# freq      584    1009

# %% [markdown]
# ### Split data according to institution type (public vs private)
#
# To find out if a given institution is private or public, use `CO_IES` in a search at https://emec.mec.gov.br/

# %% [markdown]
# Public institutions:

# %%
df_pub = df_dropped2.query('CO_IES in [56, 845, 15697]')
len(df_pub)
# Out:
# 254

# %% [markdown]
# Private institutions:

# %%
df_priv = df_dropped2.query('CO_IES in [322, 1418, 2289, 4522]')
len(df_priv)
# Out:
# 1547

# %% [markdown]
# Verify consistence after spliting.

# %%
len(df_pub.index) + len(df_priv.index) == len(df_dropped2.index)
# Out:
# True

# %% [markdown]
# #### Save intermediate data

# %%
df_pub.to_csv('../data/interim/microdados_enade_ata_2016a2018_pub.csv', index=False)

# %%
df_priv.to_csv('../data/interim/microdados_enade_ata_2016a2018_priv.csv', index=False)
